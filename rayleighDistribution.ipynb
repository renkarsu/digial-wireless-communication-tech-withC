# %% [markdown]
# <a href="https://colab.research.google.com/github/renkarsu/digital-wireless-communication-tech-withC/blob/master/rayleighDistribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

#d = np.loadtxt(fname='check_rayl_result.txt',delimiter='\t', usecols=(range(0,10000)), unpack=False)
d = np.loadtxt(fname='check_rayl_result.txt',delimiter='\t')
#a = np.arrange(0.0 ,5.0, 0.1)
ax.hist(d, bins=500, normed=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   # Remove the CWD from sys.path while we load stuff.
# (array([0.01348065, 0.02546345, 0.01947205, 0.05242475, 0.05991401,
#         0.08088391, 0.10185381, 0.08987101, 0.10484951, 0.14229576,
#         0.14229576, 0.14678931, 0.15577641, 0.16626136, 0.21569042,
#         0.22317967, 0.20969902, 0.22317967, 0.27410657, 0.23815817,
#         0.25763022, 0.28159582, 0.28159582, 0.28459152, 0.31005498,
#         0.32353563, 0.36247973, 0.33252273, 0.35798618, 0.39243673,
#         0.44486149, 0.38344963, 0.42988299, 0.43887009, 0.45834214,
#         0.43737224, 0.50477549, 0.49129484, 0.41490449, 0.48680129,
#         0.48230774, 0.49429054, 0.50926904, 0.51376259, 0.59614435,
#         0.59914005, 0.57517445, 0.5646895 , 0.6006379 , 0.579668  ,
# ...
